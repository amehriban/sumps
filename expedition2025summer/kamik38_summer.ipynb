# %%
import numpy as np
import pygimli as pg
#import pybert as pb
from pygimli.physics import ert
#from pybert.importer.exportData import exportRes2dInv
from pygimli.physics.ert.importData import importRes2dInv
import matplotlib.pyplot as plt
import pygimli.meshtools as mt
from pygimli.frameworks import PriorModelling, JointModelling
from scipy.interpolate import interp1d
import pandas as pd
import pickle
from datetime import datetime
from glob import glob

# %%
dir = "//smb.isipd.dmawi.de/projects/sparc/personal_accounts/Mehriban/expedition2025summer/"

# %%
data = ert.load(dir + '26Aug/k38_old_125cm.tx0')
# Out:
# 30/09/25 - 15:21:29 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# 30/09/25 - 15:21:29 - pyGIMLi - INFO - could not read res2dinv ... try Ascii columns
# 30/09/25 - 15:21:29 - pyGIMLi - INFO - Failed importing Ascii column file. Consider using pybert.
# 30/09/25 - 15:21:29 - pyGIMLi - INFO - No electrode positions found!
# 30/09/25 - 15:21:29 - pyGIMLi - INFO - imported:  Data: Electrodes: 48 data: 565

# %%
ert.showData(data,data['u'])
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x24fe2aae410>)

# %%
ert.showData(data)
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x24fe2fa1c50>)

# %%
data.save("//smb.isipd.dmawi.de/projects/p_thinice/06_data/ERT_data/raw_data/kamik_f38_v1_05.txt", "a b m n err iperr ip rhoa u i")
# Out:
# 1
